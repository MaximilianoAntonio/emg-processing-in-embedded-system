# %%
import numpy as np
import matplotlib.pyplot as plt
import serial
from scipy import signal
from scipy.signal import butter, filtfilt
import pandas as pd

# %%
esp = serial.Serial("COM3", 115200)
    
l = []

seg = 16
muestras = seg*1000   #está muestreando a 1000 muestras en un segundo

for i in range(m): # 4200 en el rango para 4 min
    l2 = esp.readline().decode('utf-8')
    l2 = float(l2)
    l.append(l2)

len(l)
# Out:
# 16000

# %%
tiempo = np.arange(0, seg, 0.001)  #Desde cero hasta      segundos en un muestreo de    
#len(tiempo)

fm = 1000 # 360[Hz] frecuencia de muestreo
T = 1/fm # Periodo del muestreo
largo_señal = len(l) # Largo de la señal 1
duracion_señal = T * largo_señal
tiempo_señal = np.arange(0, duracion_señal, T)

plt.figure(figsize = (15,5))
plt.plot(tiempo,l) # l
plt.grid()
plt.show()

# %%
Data = {"Señal": l, 'Tiempo': tiempo}
Data1 = pd.DataFrame(Data)
Data1.to_csv("abre y cierrrede mano 22-11-2023")
Data1
# Out:
#        Señal  Tiempo
# 0      309.0   0.000
# 1      308.0   0.001
# 2      309.0   0.002
# 3      312.0   0.003
# 4      312.0   0.004
# ...      ...     ...
# 15995  302.0  15.995
# 15996  302.0  15.996
# 15997  303.0  15.997
# 15998  303.0  15.998
# 15999  304.0  15.999
#
# [16000 rows x 2 columns]

# %%
df = pd.read_csv('Puño máximo ferni 3')
plt.figure(figsize = (15,5))
plt.plot(df['Tiempo'],df['Señal'])#,'b')
plt.grid()
plt.show()

# %%
freq1 = 1/np.mean(np.diff(tiempo_señal)) #permite obtener la frecuencia de muestreo.
b, a = butter(2, ([0.5, 5]/(freq1/2)), btype = 'bandpass') #funcion "butter" permite diseñar un filtro tipo butterworth
grafico_señal1 = filtfilt(b, a, l[0])
freq1 = int(freq1)
#signal_detrend1 = signal.detrend(grafico_señal1, -1, 'linear', 0, False)

freq2 = 1/np.mean(np.diff(tiempo_señal)) #permite obtener la frecuencia de muestreo.
x, y = butter(2, ([0.5, 5]/(freq2/2)), btype = 'bandpass') #funcion "butter" permite diseñar un filtro tipo butterworth
grafico_señal2 = filtfilt(x, y, l[1])
freq2 = int(freq2)
#signal_detrend2 = signal.detrend(grafico_señal2, -1, 'linear', 0, False)

plt.figure(figsize = (12, 4))

plt.subplot(2,1,1)
plt.plot(tiempo_señal, grafico_señal1)
plt.grid(True)

plt.subplot(2,1,2)
plt.plot(tiempo_señal, grafico_señal2)
plt.grid(True)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\ferna\OneDrive\Desktop\Proyecto de prótesis\P\ino2\Interfáz con python.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Desktop/Proyecto%20de%20pr%C3%B3tesis/P/ino2/Interf%C3%A1z%20con%20python.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> freq1 = 1/np.mean(np.diff(tiempo_señal)) #permite obtener la frecuencia de muestreo.
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Desktop/Proyecto%20de%20pr%C3%B3tesis/P/ino2/Interf%C3%A1z%20con%20python.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> b, a = butter(2, ([0.5, 5]/(freq1/2)), btype = 'bandpass') #funcion "butter" permite diseñar un filtro tipo butterworth
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Desktop/Proyecto%20de%20pr%C3%B3tesis/P/ino2/Interf%C3%A1z%20con%20python.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> grafico_señal1 = filtfilt(b, a, l[0])
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Desktop/Proyecto%20de%20pr%C3%B3tesis/P/ino2/Interf%C3%A1z%20con%20python.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> freq1 = int(freq1)
#       <a href='vscode-notebook-cell:/c%3A/Users/ferna/OneDrive/Desktop/Proyecto%20de%20pr%C3%B3tesis/P/ino2/Interf%C3%A1z%20con%20python.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> #signal_detrend1 = signal.detrend(grafico_señal1, -1, 'linear', 0, False)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\scipy\signal\_signaltools.py:4130, in filtfilt(b, a, x, axis, padtype, padlen, method, irlen)
#    4127     return y
#    4129 # method == "pad"
# -> 4130 edge, ext = _validate_pad(padtype, padlen, x, axis,
#    4131                           ntaps=max(len(a), len(b)))
#    4133 # Get the steady state of the filter's step response.
#    4134 zi = lfilter_zi(b, a)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\scipy\signal\_signaltools.py:4179, in _validate_pad(padtype, padlen, x, axis, ntaps)
#    4176     edge = padlen
#    4178 # x's 'axis' dimension must be bigger than edge.
# -> 4179 if x.shape[axis] <= edge:
#    4180     raise ValueError("The length of the input vector x must be greater "
#    4181                      "than padlen, which is %d." % edge)
#    4183 if padtype is not None and edge > 0:
#    4184     # Make an extension of length `edge` at each
#    4185     # end of the input array.
#
# IndexError: tuple index out of range
